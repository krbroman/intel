# %%
# !pip install umap-learn
# Out:
# ...
#      |████████████████████████████████| 86 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 22.1 MB/s
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.2-py3-none-any.whl size=82709 sha256=78dda42e9b9295bf52145c0ccceb839896ccb82b311b0a6ffa6f209965f3d7f8
#   Stored in directory: /root/.cache/pip/wheels/84/1b/c6/aaf68a748122632967cef4dffef68224eb16798b6793257d82
# ...
#   Created wheel for pynndescent: filename=pynndescent-0.5.5-py3-none-any.whl size=52603 sha256=e5e6185e736ff63b790c71fb2ea659116e272b8ebb926f4c0e756e663d99c294
#   Stored in directory: /root/.cache/pip/wheels/af/e9/33/04db1436df0757c42fda8ea6796d7a8586e23c85fac355f476
# Successfully built umap-learn pynndescent
# ...

# %%
import pandas as pd
from umap import UMAP
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
mnist_url = "https://www.openml.org/data/get_csv/52667/mnist_784.arff"
mnist_df = pd.read_csv(mnist_url)

# %%
plt.figure(figsize=(10, 10))
print("Алгоритм UMAP")
MNIST_e = UMAP().fit_transform(mnist_df[:20000].drop('class', axis=1))
plt.scatter(MNIST_e[:,0], MNIST_e[:,1], c=mnist_df[:20000]['class'], cmap="plasma", s=2)

plt.show()
# Out:
# Алгоритм UMAP
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
print("Алгоритм TSNE")
plt.figure(figsize=(10, 10))
MNIST_e = TSNE(n_components=2).fit_transform(mnist_df[:20000].drop('class', axis=1))
plt.scatter(MNIST_e[:,0], MNIST_e[:,1], c=mnist_df[:20000]['class'], cmap="plasma", s=2)
plt.show()
# Out:
# Алгоритм TSNE
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
print("Алгоритм PCA")
plt.figure(figsize=(10, 10))
MNIST_e = PCA(n_components=2).fit_transform(mnist_df[:20000].drop('class', axis=1))
plt.scatter(MNIST_e[:,0], MNIST_e[:,1], c=mnist_df[:20000]['class'], cmap="plasma", s=2)
plt.show()
# Out:
# Алгоритм PCA

# %%
coil_20_df = pd.read_csv('https://raw.githubusercontent.com/vaksakalli/datasets/master/coil20.csv')
plt.figure(figsize=(10, 10))
print("Алгоритм UMAP")
coil_e = UMAP().fit_transform(coil_20_df.drop('1024', axis=1))
plt.scatter(coil_e [:,0], coil_e [:,1], c=coil_20_df['1024'], cmap="plasma", s=2)

plt.show()
# Out:
# Алгоритм UMAP

# %%
plt.figure(figsize=(10, 10))
print("Алгоритм TSNE")
coil_e = TSNE(n_components=2).fit_transform(coil_20_df.drop('1024', axis=1))
plt.scatter(coil_e [:,0], coil_e [:,1], c=coil_20_df['1024'], cmap="plasma", s=2)

plt.show()
# Out:
# Алгоритм TSNE
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
plt.figure(figsize=(10, 10))
print("Алгоритм PCA")
coil_e = PCA(n_components=2).fit_transform(coil_20_df.drop('1024', axis=1))
plt.scatter(coil_e [:,0], coil_e [:,1], c=coil_20_df['1024'], cmap="plasma", s=2)

plt.show()
# Out:
# Алгоритм PCA

# %%
# !pip install gensim
from gensim.models import Word2Vec
from gensim.downloader import load
g_n_df = load('word2vec-google-news-300')
plt.figure(figsize=(10, 10))
print("Алгоритм UMAP")
g_n_e = UMAP().fit_transform(g_n_df.vectors[:20000])
plt.scatter(g_n_e[:,0], g_n_e[:,1], s=2)
plt.show()
# Out:
# ...
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Алгоритм UMAP

# %%
plt.figure(figsize=(10, 10))
print("Алгоритм TSNE")
g_n_e = TSNE(n_components=2).fit_transform(g_n_df.vectors[:20000])
plt.scatter(g_n_e[:,0], g_n_e[:,1], s=2)
plt.show()
# Out:
# Алгоритм TSNE
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
plt.figure(figsize=(10, 10))
print("Алгоритм PCA")
g_n_e = PCA(n_components=2).fit_transform(g_n_df.vectors[:20000])
plt.scatter(g_n_e[:,0], g_n_e[:,1], s=2)
plt.show()
# Out:
# Алгоритм PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# f_mnist_df = pd.read_csv(r"C:\Users\1\Downloads\train.csv")
f_mnist_df = pd.read_csv("/content/drive/MyDrive/train.csv")
print(f_mnist_df.columns)
f_mnist_df = f_mnist_df.drop('Id', axis=1)
plt.figure(figsize=(10, 10))
print("Алгоритм UMAP")
f_mnist_e = UMAP().fit_transform(f_mnist_df[:20000].drop('Category', axis=1))
plt.scatter(f_mnist_e [:,0], f_mnist_e [:,1], c=f_mnist_df[:20000]['Category'], cmap="plasma", s=2)
plt.show()
# Out:
# Index(['Id', 'Category', 'Pixel000', 'Pixel001', 'Pixel002', 'Pixel003',
#        'Pixel004', 'Pixel005', 'Pixel006', 'Pixel007',
#        ...
#        'Pixel774', 'Pixel775', 'Pixel776', 'Pixel777', 'Pixel778', 'Pixel779',
#        'Pixel780', 'Pixel781', 'Pixel782', 'Pixel783'],
#       dtype='object', length=786)
# Алгоритм UMAP

# %%
plt.figure(figsize=(10, 10))
print("Алгоритм TSNE")
f_mnist_e = TSNE(n_components=2).fit_transform(f_mnist_df[:20000].drop('Category', axis=1))
plt.scatter(f_mnist_e [:,0], f_mnist_e [:,1], c=f_mnist_df[:20000]['Category'], cmap="plasma", s=2)
plt.show()
# Out:
# Алгоритм TSNE
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
plt.figure(figsize=(10, 10))
print("Алгоритм PCA")
f_mnist_e = PCA(n_components=2).fit_transform(f_mnist_df[:20000].drop('Category', axis=1))
plt.scatter(f_mnist_e [:,0], f_mnist_e [:,1], c=f_mnist_df[:20000]['Category'], cmap="plasma", s=2)
plt.show()
# Out:
# Алгоритм PCA
